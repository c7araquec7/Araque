# %% [markdown]
# <a href="https://colab.research.google.com/github/c7araquec7/Araque/blob/main/Taller_Forecasting_Ocupacion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Cargar dataset de ocupacion de sitios de parqueo
data = pd.read_csv('SJ.csv')

# %%
# Revisar cabecera y cola del dataset
print(data.head())
print(data.tail())
# Out:
#       date  idCompany  numTrx
# 0  2022-08          1   68599
# 1  2022-09          1   86862
# 2  2022-10          1   99611
# 3  2022-11          1  109018
# 4  2022-12          1  115665
#        date  idCompany  numTrx
# 13  2023-09          1  126851
# 14  2023-10          1  137539
# 15  2023-11          1  145327
# 16  2023-12          1  135537
# 17  2024-01          1  148111

# %%
# Formatear la columna de fecha como año y mes
data["date"] = pd.to_datetime(data["date"],format='%Y-%m')
data.head()
# Out:
#         date  idCompany  numTrx
# 0 2022-08-01          1   68599
# 1 2022-09-01          1   86862
# 2 2022-10-01          1   99611
# 3 2022-11-01          1  109018
# 4 2022-12-01          1  115665

# %%
# Verificar el nombre de los meses del dataset para comprobar que el formateo es correcto
data["date"].dt.month_name().unique()
# Out:
# array(['August', 'September', 'October', 'November', 'December',
#        'January', 'February', 'March', 'April', 'May', 'June', 'July'],
#       dtype=object)

# %%
# Contar el numero de datos del dataset
data.count()
# Out:
# date         18
# idCompany    18
# numTrx       18
# dtype: int64

# %%
# Obtener una estadistica descriptiva básica del dataset, verificar si hay algo anormal
data.describe()
# Out:
#                       date  idCompany         numTrx
# count                   18       18.0      18.000000
# mean   2023-04-16 18:40:00        1.0  120111.833333
# min    2022-08-01 00:00:00        1.0   68599.000000
# 25%    2022-12-08 18:00:00        1.0  110679.750000
# 50%    2023-04-16 00:00:00        1.0  125518.500000
# 75%    2023-08-24 06:00:00        1.0  135321.000000
# max    2024-01-01 00:00:00        1.0  148111.000000
# std                    NaN        0.0   20840.047288

# %%
# Revisar si el ldataset tiene datos nullos
data.isnull().sum()
# Out:
# date         0
# idCompany    0
# numTrx       0
# dtype: int64

# %%
# Establecer el campo fecha como index del dataframe
data = data.set_index('date')

# %%
# Verificar nuevamente el head de la tabla y comprobar que el index ahora sea la fecha
data.head()
# Out:
#             idCompany  numTrx
# date
# 2022-08-01          1   68599
# 2022-09-01          1   86862
# 2022-10-01          1   99611
# 2022-11-01          1  109018
# 2022-12-01          1  115665

# %%
# Realizar una grafica de tendencia del numero de espacios ocupados en el tiempo
sns.lineplot(data=data)
# Out:
# <Axes: xlabel='date'>

# %%
# Eliminar las columnas que no necesiten para realizar un sistema de prediccion de ocupacion de parqueo
data_copy = data.copy(deep=True)
data_copy = data_copy.drop("idCompany", axis=1)
data_copy
# Out:
#             numTrx
# date
# 2022-08-01   68599
# 2022-09-01   86862
# 2022-10-01   99611
# 2022-11-01  109018
# 2022-12-01  115665
# 2023-01-01  116672
# 2023-02-01  118194
# 2023-03-01  134673
# 2023-04-01  100997
# 2023-05-01  129538
# 2023-06-01  124599
# 2023-07-01  126438
# 2023-08-01  137782
# 2023-09-01  126851
# 2023-10-01  137539
# 2023-11-01  145327
# 2023-12-01  135537
# 2024-01-01  148111

# %%
# Escalar entre -1 y 1 los datos de la variable a predecir
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(-1,1))
scaler.fit(data_copy)
scaled_data = scaler.transform(data_copy)
scaled_data
# Out:
# array([[-1.        ],
#        [-0.5406228 ],
#        [-0.21994164],
#        [ 0.01667673],
#        [ 0.18387162],
#        [ 0.20920113],
#        [ 0.24748466],
#        [ 0.66198813],
#        [-0.18507898],
#        [ 0.53282523],
#        [ 0.40859241],
#        [ 0.45484958],
#        [ 0.74019016],
#        [ 0.46523795],
#        [ 0.73407788],
#        [ 0.92997283],
#        [ 0.6837207 ],
#        [ 1.        ]])

# %%
# Definir una ventana temporal adecuada para la prediccion y establecer las listas
# xtrain y ytrain para el entrenamiento
steps = 2
xtrain = []
ytrain = []
for i in range(len(scaled_data)-steps):
    xtrain.append(scaled_data[i:i+steps])
    ytrain.append(scaled_data[i+steps])

# %%
# Convertir las listas en arrays de numpy
xtrain = np.asanyarray(xtrain)
ytrain = np.asanyarray(ytrain)

# %%
# Verificar el shape de los datos de entrenamiento (variable independiente y dependiente)
print(xtrain.shape)
print(ytrain.shape)
# Out:
# (16, 2, 1)
# (16, 1)

# %%
# Construir un modelo LSTM para realizar la predicción que tenga la siguiente arquitectura

# Una capa LSTM de 256 neuronas con activación relu
# Una capa LSTM de 256 neuronas con activación relu
# Una capa LSTM de 128 neuronas con activación relu
# Una capa LSTM de 64 neuronas con activación relu
# Una capa LSTM de 32 neuronas con activación relu
# Una capa LSTM de 16 neuronas con activación relu (esta seria la ultima capa LSTM)
# Agregar operaciones de Dropout de 7% despues de cada capa LSTM
# Agregar en la etapa final una red densa con dos capas con 64 neuronas y 32 neuronas
# Finalmente agregar una capa densa de salida
# Imprimir el summary del  modelo
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

model = Sequential()
model.add(LSTM(units=256,return_sequences=True,activation='relu', input_shape=(20,1)))
model.add(Dropout(0.07))
model.add(LSTM(units=128,return_sequences=True,activation='relu'))
model.add(Dropout(0.07))
model.add(LSTM(units=64,return_sequences=True,activation='relu'))
model.add(Dropout(0.07))
model.add(LSTM(units=32,return_sequences=True,activation='relu'))
model.add(Dropout(0.07))
model.add(LSTM(units=16,return_sequences=False,activation='relu'))
model.add(Dropout(0.07))
model.add(Dense(64))
model.add(Dense(32))
model.add(Dense(1))
model.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_10 (LSTM)                       │ (None, 20, 256)             │         264,192 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_10 (Dropout)                 │ (None, 20, 256)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_11 (LSTM)                       │ (None, 20, 128)             │         197,120 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_11 (Dropout)                 │ (None, 20, 128)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_12 (LSTM)                       │ (None, 20, 64)              │          49,408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_12 (Dropout)                 │ (None, 20, 64)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_13 (LSTM)                       │ (None, 20, 32)              │          12,416 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_13 (Dropout)                 │ (None, 20, 32)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_14 (LSTM)                       │ (None, 16)                  │           3,136 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_14 (Dropout)                 │ (None, 16)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 64)                  │           1,088 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 529,473 (2.02 MB)
#  Trainable params: 529,473 (2.02 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compilar el modelo con una funcion de error mse y un optimizador adam
model.compile(optimizer='adam',loss='mse')

# %%
# Entrenar el modelo durante 100 epocas
# Usar el 10% de los datos de entrenamiento para validacion
# Usar un batch size de 16
history = model.fit(xtrain,ytrain,epochs=100,validation_split=0.1,batch_size=16,verbose=1)
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 10s 10s/step - loss: 0.2490 - val_loss: 0.7017
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.2352 - val_loss: 0.6690
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.2214 - val_loss: 0.6354
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.2077 - val_loss: 0.6008
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.1944 - val_loss: 0.5655
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.1811 - val_loss: 0.5295
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 0.1691 - val_loss: 0.4929
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.1570 - val_loss: 0.4561
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - loss: 0.1462 - val_loss: 0.4192
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.1362 - val_loss: 0.3825
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.1273 - val_loss: 0.3465
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.1211 - val_loss: 0.3116
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.1167 - val_loss: 0.2785
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.1120 - val_loss: 0.2478
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.1121 - val_loss: 0.2206
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.1137 - val_loss: 0.1978
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.1165 - val_loss: 0.1804
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - loss: 0.1188 - val_loss: 0.1685
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.1204 - val_loss: 0.1617
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.1218 - val_loss: 0.1597
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.1235 - val_loss: 0.1616
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.1219 - val_loss: 0.1665
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 0.1186 - val_loss: 0.1738
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.1188 - val_loss: 0.1831
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.1158 - val_loss: 0.1937
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.1150 - val_loss: 0.2051
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.1135 - val_loss: 0.2167
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.1116 - val_loss: 0.2280
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.1124 - val_loss: 0.2387
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.1120 - val_loss: 0.2486
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 0.1113 - val_loss: 0.2572
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.1112 - val_loss: 0.2645
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.1104 - val_loss: 0.2701
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.1114 - val_loss: 0.2741
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.1109 - val_loss: 0.2763
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.1114 - val_loss: 0.2770
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.1108 - val_loss: 0.2761
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 0.1114 - val_loss: 0.2737
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.1099 - val_loss: 0.2698
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.1099 - val_loss: 0.2645
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.1099 - val_loss: 0.2581
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - loss: 0.1066 - val_loss: 0.2503
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.1083 - val_loss: 0.2417
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - loss: 0.1077 - val_loss: 0.2320
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.1054 - val_loss: 0.2213
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.1053 - val_loss: 0.2097
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.1056 - val_loss: 0.1973
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.1033 - val_loss: 0.1839
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.1023 - val_loss: 0.1693
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 0.0979 - val_loss: 0.1533
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0993 - val_loss: 0.1357
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0929 - val_loss: 0.1164
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0937 - val_loss: 0.0952
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 0.0937 - val_loss: 0.0743
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - loss: 0.0887 - val_loss: 0.0545
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.0882 - val_loss: 0.0386
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0853 - val_loss: 0.0260
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0781 - val_loss: 0.0174
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0774 - val_loss: 0.0163
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 0.0738 - val_loss: 0.0155
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0771 - val_loss: 0.0153
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - loss: 0.0665 - val_loss: 0.0120
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0782 - val_loss: 0.0144
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - loss: 0.0672 - val_loss: 0.0314
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.0793 - val_loss: 0.0465
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0623 - val_loss: 0.0597
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 0.0686 - val_loss: 0.0454
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0651 - val_loss: 0.0611
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0741 - val_loss: 0.0571
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.0673 - val_loss: 0.0303
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 0.0714 - val_loss: 0.0290
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.0701 - val_loss: 0.0423
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0806 - val_loss: 0.0517
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0564 - val_loss: 0.0571
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 0.0608 - val_loss: 0.0949
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0670 - val_loss: 0.0632
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0641 - val_loss: 0.0311
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 0.0742 - val_loss: 0.0122
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0630 - val_loss: 0.0111
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 0.0698 - val_loss: 0.0120
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 0.0683 - val_loss: 0.0226
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0640 - val_loss: 0.0573
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.0668 - val_loss: 0.0573
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.0688 - val_loss: 0.0454
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 0.0687 - val_loss: 0.0167
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - loss: 0.0701 - val_loss: 0.0104
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - loss: 0.0657 - val_loss: 0.0146
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - loss: 0.0719 - val_loss: 0.0194
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - loss: 0.0654 - val_loss: 0.0185
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.0648 - val_loss: 0.0135
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - loss: 0.0719 - val_loss: 0.0114
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - loss: 0.0616 - val_loss: 0.0203
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 0.0573 - val_loss: 0.0358
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0680 - val_loss: 0.0395
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 0.0732 - val_loss: 0.0202
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 0.0554 - val_loss: 0.0120
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - loss: 0.0578 - val_loss: 0.0136
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 0.0593 - val_loss: 0.0176
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 0.0700 - val_loss: 0.0195
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - loss: 0.0628 - val_loss: 0.0173

# %%
# Grafifcar el loss y loss de validacion para verificar que no haya overfitting
plt.plot(history.history['loss'],label='loss')
plt.plot(history.history['val_loss'],label='val_loss')
plt.legend(['train loss','val loss'])

# %%
# Guardar el modelo y salvarlo en disco
model.save('Forecasting_Ocupacion.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Tome N registros historicos de su dataset y realice la predicción de ocupación para un mes particular

N = 2

historical_data = data['numTrx'][:-1][-N:].values.reshape(-1, 1)
print(historical_data)
historical_data_scaled = scaler.transform(historical_data)
X_pred = historical_data_scaled.reshape(1, N, 1)
print(X_pred)

prediction_scaled = model.predict(X_pred)
prediction = scaler.inverse_transform(prediction_scaled)
# Imprime la predicción
print('Predicción:', prediction[0, 0])
# Out:
# [[145327]
#  [135537]]
# [[[0.92997283]
#   [0.6837207 ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Predicción: 141028.69
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %%
# Proponga una arquitectura que permita recibir como parametros de entrada no solo los historicos de la
# serie temporal sino tambien información adicional relevante como por ejemplo el mes para el cual se
# realiza la predicción, o el número de dias festivos del mes de predicción
# agregar a la red neuronal no solo el resumen sino tambien otra red neuronal
historical_data = data['numTrx'][:-1][-N:].values.reshape(-1, 1)
print(historical_data)
historical_data_scaled = scaler.transform(historical_data)
X_pred = historical_data_scaled.reshape(1, N, 1)
print(X_pred)

prediction_scaled = model.predict(X_pred)
prediction = scaler.inverse_transform(prediction_scaled)
# Imprime la predicción
print('Predicción:', prediction[0, 0])
# Out:
# [[145327]
#  [135537]]
# [[[0.92997283]
#   [0.6837207 ]]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Predicción: 141028.69
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
